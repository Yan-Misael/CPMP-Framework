# %% [markdown]
# # Generación de datos de entrenamiento

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Generación de instancias

# %%
from generation.instances import generate_instances, FullRandomGenerator
from generation.instances import generate_instances, RandomMovesGenerator

S = 9
r_list = [2, 3]

H = S + 2
N = S * S
seed = 42

instance_generator = FullRandomGenerator(H=H, S=S, N=N, seed=seed)
generate_instances(f"E{S}-{S}-RFull", instance_generator, 10000)

for r in r_list:
    instance_generator = RandomMovesGenerator(H=H, S=S, N=N, r=r, seed=seed)
    generate_instances(f"E{S}-{S}-R{r}", instance_generator, 10000)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 12
#       8 N = S * S
#       9 seed = 42
#      10
#      11 instance_generator = FullRandomGenerator(H=H, S=S, N=N, seed=seed)
# ---> 12 generate_instances(f"E{S}-{S}-RFull", instance_generator, 10000)
#      13
#      14 for r in r_list:
#      15     instance_generator = RandomMovesGenerator(H=H, S=S, N=N, r=r, seed=seed)
#
# File ~/Escritorio/CPMP-Framework/src/generation/instances/__init__.py:13, in generate_instances(basename, instance_generator, amount)
#      11 def generate_instances(basename: str, instance_generator: InstanceGenerator, amount: int):
#      12     os.makedirs(INSTANCE_FOLDER / basename, exist_ok=True)
# ---> 13     instances = instance_generator.generate_instances(amount)
#      15     for i, inst in enumerate(instances):
#      16         filepath = INSTANCE_FOLDER / basename / f'{basename}-{i}.txt'
#
# File ~/Escritorio/CPMP-Framework/src/generation/instances/generators/full_random.py:7, in FullRandomGenerator.generate_instances(self, amount)
#       5 while len(self.instances) < amount:
#       6     stacks = self.generate_stacks(self.H, self.S, self.N, sorted=False)
# ----> 7     self.add_instance(stacks)
#       8 return self.instances
#
# File ~/Escritorio/CPMP-Framework/src/generation/instances/instance_generator.py:36, in InstanceGenerator.add_instance(self, instance)
#      35 def add_instance(self, instance):
# ---> 36     instance_hash = tuple(tuple(stack) for stack in instance)
#      37     if tuple(instance_hash) in self.instance_set: return False
#      39     layout = Layout(instance, self.H)
#
# File ~/Escritorio/CPMP-Framework/src/generation/instances/instance_generator.py:36, in <genexpr>(.0)
#      35 def add_instance(self, instance):
# ---> 36     instance_hash = tuple(tuple(stack) for stack in instance)
#      37     if tuple(instance_hash) in self.instance_set: return False
#      39     layout = Layout(instance, self.H)
#
# KeyboardInterrupt:

# %%
from generation.instances import generate_instances, UniformCostGenerator

S = 3
instance_generator = UniformCostGenerator(S=S, seed=44)
generate_instances(f"E{S}-{S}-Uniform-RL2", instance_generator, 5000)

# %% [markdown]
# ## Generación de datos (SL)

# %%
from generation.data import generate_data_sl
from generation.adapters.input import EnrichedLayoutAdapter, Layout4DAdapterV2
from generation.adapters.input.stack_features import StackFeaturesAdapterV1
from generation.adapters.output import ActionAdapter

folders = ["E9-9-Uniform-SL"]
H = 11
max_steps = 500
input_adapter_config = (EnrichedLayoutAdapter, Layout4DAdapterV2, StackFeaturesAdapterV1)
output_adapter_config = (ActionAdapter, )
num_workers = 12
output_prefix = "actions2F"

generate_data_sl(folders, H, max_steps, input_adapter_config, output_adapter_config, num_workers, output_prefix)
# Out:
# Datos guardados en: /home/oscar/Escritorio/CPMP-Framework/data/actions2F_E9-9-Uniform-SL.data (Tamaño 100000)

# %%
from generation.data import generate_data_sl
from generation.adapters.input import EnrichedLayoutAdapter, Layout4DAdapterV3
from generation.adapters.input.stack_features import StackFeaturesAdapterV1
from generation.adapters.output import ActionAdapter

folders = ["E3-3-Uniform-RL2"]
H = 5
max_steps = 500
input_adapter_config = (EnrichedLayoutAdapter, Layout4DAdapterV3, StackFeaturesAdapterV1)
output_adapter_config = (ActionAdapter, )
num_workers = 12
output_prefix = "actions5F"

generate_data_sl(folders, H, max_steps, input_adapter_config, output_adapter_config, num_workers, output_prefix)
# Out:
# Datos guardados en: /home/oscar/Escritorio/CPMP-Framework/data/actions5F_E3-3-Uniform-RL2.data (Tamaño 5000)

# %%
from generation.data import generate_data_sl
from generation.adapters.input import EnrichedLayoutAdapter, Layout4DAdapterV3
from generation.adapters.input.stack_features import StackFeaturesAdapterV1
from generation.adapters.output import ActionAdapter

folders = ["E9-9-Uniform"]
H = 11
max_steps = 500
input_adapter_config = (EnrichedLayoutAdapter, Layout4DAdapterV3, StackFeaturesAdapterV1)
output_adapter_config = (ActionAdapter, )
num_workers = 12
output_prefix = "actions5F"

generate_data_sl(folders, H, max_steps, input_adapter_config, output_adapter_config, num_workers, output_prefix)
# Out:
# Datos guardados en: /home/oscar/Escritorio/CPMP-Framework/data/actions5F_E9-9-Uniform.data (Tamaño 20000)

# %%
import numpy as np

def mu(S, R):
    return ((0.9878 * S**2.1644) * R**0.8581) / (np.exp(0.4350 * S + 1.4065) + R**0.8581)

mu(9, 1)
# Out:
# np.float64(0.5582347641228002)

# %%
from generation.data import generate_data_sl
from generation.adapters.input import EnrichedLayoutAdapter, Layout4DAdapterV2
from generation.adapters.input.stack_features import StackFeaturesAdapterV1
from generation.adapters.output import ActionAdapter

S = 9

folders = [f"E{S}-{S}-R2", f"E{S}-{S}-R3"]
H = S + 2
max_steps = 9999
input_adapter_config = (EnrichedLayoutAdapter, Layout4DAdapterV2, StackFeaturesAdapterV1)
output_adapter_config = (ActionAdapter, )
num_workers = 12
output_prefix = "actions5F"

generate_data_sl(folders, H, max_steps, input_adapter_config, output_adapter_config, num_workers, output_prefix)
# Out:
# Datos guardados en: /home/oscar/Escritorio/CPMP-Framework/data/actions5F_E9-9-R2.data (Tamaño 10000)
# Datos guardados en: /home/oscar/Escritorio/CPMP-Framework/data/actions5F_E9-9-R3.data (Tamaño 10000)

# %%
from generation.data import generate_data_sl
from generation.adapters.input import EnrichedLayoutAdapter, Layout4DAdapterV2
from generation.adapters.input.stack_features import StackFeaturesAdapterV1
from generation.adapters.output import ActionAdapter

S = 5

folders = [f"E{S}-{S}-R5", f"E{S}-{S}-R20", f"E{S}-{S}-R50", f"E{S}-{S}-R100", f"E{S}-{S}-R200", f"E{S}-{S}-R500", f"E{S}-{S}-RFull"]
H = S + 2
max_steps = 9999
input_adapter_config = (EnrichedLayoutAdapter, Layout4DAdapterV2, StackFeaturesAdapterV1)
output_adapter_config = (ActionAdapter, )
num_workers = 12
output_prefix = "actions5F"

generate_data_sl(folders, H, max_steps, input_adapter_config, output_adapter_config, num_workers, output_prefix)
# Out:
# Datos guardados en: /home/oscar/Escritorio/CPMP-Framework/data/actions5F_E5-5-R5.data (Tamaño 10000)
# Datos guardados en: /home/oscar/Escritorio/CPMP-Framework/data/actions5F_E5-5-R20.data (Tamaño 10000)
# Datos guardados en: /home/oscar/Escritorio/CPMP-Framework/data/actions5F_E5-5-R50.data (Tamaño 10000)
# Datos guardados en: /home/oscar/Escritorio/CPMP-Framework/data/actions5F_E5-5-R100.data (Tamaño 10000)
# Datos guardados en: /home/oscar/Escritorio/CPMP-Framework/data/actions5F_E5-5-R200.data (Tamaño 10000)
# Datos guardados en: /home/oscar/Escritorio/CPMP-Framework/data/actions5F_E5-5-R500.data (Tamaño 10000)
# Datos guardados en: /home/oscar/Escritorio/CPMP-Framework/data/actions5F_E5-5-RFull.data (Tamaño 10000)

# %%
from generation.data import generate_data_sl
from generation.adapters.input import EnrichedLayoutAdapter, Layout4DAdapterV2
from generation.adapters.input.stack_features import StackFeaturesAdapterV1
from generation.adapters.output import ActionAdapter

S = 3

folders = [f"E{S}-{S}-R5", f"E{S}-{S}-R20", f"E{S}-{S}-R50", f"E{S}-{S}-R100", f"E{S}-{S}-R200", f"E{S}-{S}-R500", f"E{S}-{S}-RFull"]
H = S + 2
max_steps = 9999
input_adapter_config = (EnrichedLayoutAdapter, Layout4DAdapterV2, StackFeaturesAdapterV1)
output_adapter_config = (ActionAdapter, )
num_workers = 12
output_prefix = "actions5F"

generate_data_sl(folders, H, max_steps, input_adapter_config, output_adapter_config, num_workers, output_prefix)
# Out:
# Datos guardados en: /home/oscar/Escritorio/CPMP-Framework/data/actions5F_E3-3-R5.data (Tamaño 10000)
# Datos guardados en: /home/oscar/Escritorio/CPMP-Framework/data/actions5F_E3-3-R20.data (Tamaño 10000)
# Datos guardados en: /home/oscar/Escritorio/CPMP-Framework/data/actions5F_E3-3-R50.data (Tamaño 10000)
# Datos guardados en: /home/oscar/Escritorio/CPMP-Framework/data/actions5F_E3-3-R100.data (Tamaño 10000)
# Datos guardados en: /home/oscar/Escritorio/CPMP-Framework/data/actions5F_E3-3-R200.data (Tamaño 10000)
# Datos guardados en: /home/oscar/Escritorio/CPMP-Framework/data/actions5F_E3-3-R500.data (Tamaño 10000)
# Datos guardados en: /home/oscar/Escritorio/CPMP-Framework/data/actions5F_E3-3-RFull.data (Tamaño 10000)

# %%
from generation.data import generate_data_sl
from generation.adapters.input import EnrichedLayoutAdapter, Layout4DAdapterV2
from generation.adapters.input.stack_features import StackFeaturesAdapterV1
from generation.adapters.output import ActionAdapter

folders = ["E7-7-R20", "E7-7-R50", "E7-7-R100", "E7-7-R200", "E7-7-RFull"]
H = 9
max_steps = 100
input_adapter_config = (EnrichedLayoutAdapter, Layout4DAdapterV2, StackFeaturesAdapterV1)
output_adapter_config = (ActionAdapter, )
num_workers = 12
output_prefix = "actions5F"

generate_data_sl(folders, H, max_steps, input_adapter_config, output_adapter_config, num_workers, output_prefix)
# Out:
# Datos guardados en: /home/oscar/Escritorio/CPMP-Framework/data/actions5F_E7-7-R20.data (Tamaño 9946)
# Datos guardados en: /home/oscar/Escritorio/CPMP-Framework/data/actions5F_E7-7-R50.data (Tamaño 10000)
# Datos guardados en: /home/oscar/Escritorio/CPMP-Framework/data/actions5F_E7-7-R100.data (Tamaño 10000)
# Datos guardados en: /home/oscar/Escritorio/CPMP-Framework/data/actions5F_E7-7-R200.data (Tamaño 10000)
# Datos guardados en: /home/oscar/Escritorio/CPMP-Framework/data/actions5F_E7-7-RFull.data (Tamaño 10000)

# %%
from generation.data import generate_data_sl
from generation.adapters.input import EnrichedLayoutAdapter, Layout4DAdapterV2
from generation.adapters.input.stack_features import StackFeaturesAdapterV1
from generation.adapters.output import ActionAdapter

folders = ["E9-9-R20", "E9-9-R50", "E9-9-R100", "E9-9-R200", "E9-9-RFull"]
H = 11
max_steps = 150
input_adapter_config = (EnrichedLayoutAdapter, Layout4DAdapterV2, StackFeaturesAdapterV1)
output_adapter_config = (ActionAdapter, )
num_workers = 12
output_prefix = "actions5F"

generate_data_sl(folders, H, max_steps, input_adapter_config, output_adapter_config, num_workers, output_prefix)
# Out:
# Datos guardados en: /home/oscar/Escritorio/CPMP-Framework/data/actions5F_E9-9-R20.data (Tamaño 9976)
# Datos guardados en: /home/oscar/Escritorio/CPMP-Framework/data/actions5F_E9-9-R50.data (Tamaño 10000)
# Datos guardados en: /home/oscar/Escritorio/CPMP-Framework/data/actions5F_E9-9-R100.data (Tamaño 10000)
# Datos guardados en: /home/oscar/Escritorio/CPMP-Framework/data/actions5F_E9-9-R200.data (Tamaño 10000)
# Datos guardados en: /home/oscar/Escritorio/CPMP-Framework/data/actions5F_E9-9-RFull.data (Tamaño 10000)

# %%
## Generación de datasets por dificultad
## Costo = número de pasos

from preprocessing.dataset import generate_dataset

prefix = "actions5F"
data_files = [f"{prefix}_E5-5-R20.data", f"{prefix}_E5-5-R50.data", f"{prefix}_E5-5-R100.data", f"{prefix}_E5-5-R200.data", f"{prefix}_E5-5-RFull.data"]
max_size = 5000
cost_intervals = [(1, 10), (11, 30)]

for min_cost, max_cost in cost_intervals:
    output_name = f"{prefix}_E5-5-C{min_cost}-{max_cost}.data"
    generate_dataset(data_files, output_name, min_cost, max_cost, max_size)
# Out:
# Dataset generado exitosamente en: /home/oscar/Escritorio/CPMP-Framework/data/actions5F_E5-5-C1-10.data (Tamaño 5000)
# Dataset generado exitosamente en: /home/oscar/Escritorio/CPMP-Framework/data/actions5F_E5-5-C11-30.data (Tamaño 5000)

# %%
## Generación de datasets por dificultad
## Costo = número de pasos

from preprocessing.dataset import generate_dataset

prefix = "actions5F"
data_files = [f"{prefix}_E7-7-R20.data", f"{prefix}_E7-7-R50.data", f"{prefix}_E7-7-R100.data", f"{prefix}_E7-7-R200.data", f"{prefix}_E7-7-RFull.data"]
max_size = 5000
cost_intervals = [(1, 10), (11, 30), (31, 60)]

for min_cost, max_cost in cost_intervals:
    output_name = f"{prefix}_E7-7-C{min_cost}-{max_cost}.data"
    generate_dataset(data_files, output_name, min_cost, max_cost, max_size)
# Out:
# Dataset generado exitosamente en: /home/oscar/Escritorio/CPMP-Framework/data/actions5F_E7-7-C1-10.data (Tamaño 5000)
# Dataset generado exitosamente en: /home/oscar/Escritorio/CPMP-Framework/data/actions5F_E7-7-C11-30.data (Tamaño 5000)
# Dataset generado exitosamente en: /home/oscar/Escritorio/CPMP-Framework/data/actions5F_E7-7-C31-60.data (Tamaño 5000)

# %%
## Generación de datasets por dificultad
## Costo = número de pasos

from preprocessing.dataset import generate_dataset

prefix = "actions5F"
data_files = [f"{prefix}_E9-9-R20.data", f"{prefix}_E9-9-R50.data", f"{prefix}_E9-9-R100.data", f"{prefix}_E9-9-R200.data", f"{prefix}_E9-9-RFull.data"]
max_size = 5000
cost_intervals = [(1, 10), (11, 30), (31, 60), (61, 100)]

for min_cost, max_cost in cost_intervals:
    output_name = f"{prefix}_E9-9-C{min_cost}-{max_cost}.data"
    generate_dataset(data_files, output_name, min_cost, max_cost, max_size)
# Out:
# Dataset generado exitosamente en: /home/oscar/Escritorio/CPMP-Framework/data/actions5F_E9-9-C1-10.data (Tamaño 5000)
# Dataset generado exitosamente en: /home/oscar/Escritorio/CPMP-Framework/data/actions5F_E9-9-C11-30.data (Tamaño 5000)
# Dataset generado exitosamente en: /home/oscar/Escritorio/CPMP-Framework/data/actions5F_E9-9-C31-60.data (Tamaño 5000)
# Dataset generado exitosamente en: /home/oscar/Escritorio/CPMP-Framework/data/actions5F_E9-9-C61-100.data (Tamaño 49)

# %%
# Concatenamos los datasets
from preprocessing.dataset import generate_dataset

data_files = ["actions2F_E9-9-Uniform-SL.data"]
output_name = "actions2F_E9-9-Uniform-SL-50k.data"

generate_dataset(data_files, output_name, max_cost=116, max_size=50000)
# Out:
# Dataset generado exitosamente en: /home/oscar/Escritorio/CPMP-Framework/data/actions2F_E9-9-Uniform-SL-50k.data (Tamaño 50000)

# %%
# Concatenamos los datasets
from preprocessing.dataset import generate_dataset

data_files = ["actions2F_E5-5-Uniform-SL-50k.data", "actions2F_E7-7-Uniform-SL-50k.data", "actions2F_E9-9-Uniform-SL-50k.data"]
output_name = "actions2F-SL.data"

generate_dataset(data_files, output_name)
# Out:
# Dataset generado exitosamente en: /home/oscar/Escritorio/CPMP-Framework/data/actions2F-SL.data (Tamaño 150000)

# %% [markdown]
# ## Generación de datos (RL)

# %%
## La generación de datos ocurre dentro del entrenamiento
## NO es necesario generarlos manualmente.

from generation.data import split_instances, generate_data_rl 
from generation.adapters.input import EnrichedLayoutAdapter, Layout4DAdapterV2
from generation.adapters.input.stack_features import StackFeaturesAdapterV1
from generation.adapters.output import ActionAdapter
from training.training import load_model
from models.cpmp_transformer_v5 import CPMPTransformer

folders = ["E5-5-test"]
H = 7
max_steps = 50
input_adapter_config = (EnrichedLayoutAdapter, Layout4DAdapterV2, StackFeaturesAdapterV1)
output_adapter_config = (ActionAdapter, )
model = load_model(CPMPTransformer, "best_v5")
batch_size = 32
num_workers = 12
output_name = "E5-5-test-rl.data"

# Divide las instancias en dos conjuntos (entrenamiento y validación)
# Asignamos el 80% para entrenamiento y el 20% para validación 
instance_files, _ = split_instances(folders, 0.80, 0.20, 42)

generate_data_rl(instance_files, H, max_steps, input_adapter_config, output_adapter_config, model, batch_size, num_workers, output_name)

# %%
## La generación de datos ocurre dentro del entrenamiento
## NO es necesario generarlos manualmente.

from generation.data import split_instances, generate_data_rl 
from generation.adapters.input import EnrichedLayoutAdapter, Layout4DAdapterV2
from generation.adapters.input.stack_features import StackFeaturesAdapterV1
from generation.adapters.output import CostAdapter
from training.training import load_model
from models.cpmp_transformer_v5 import CPMPTransformer

folders = ["E5-5-R20", "E5-5-R50", "E5-5-R100", "E5-5-RFull"]

for folder in folders:
    H = 7
    max_steps = 50
    input_adapter_config = (EnrichedLayoutAdapter, Layout4DAdapterV2, StackFeaturesAdapterV1)
    output_adapter_config = (CostAdapter, )
    model = load_model(CPMPTransformer, "best_rl")
    batch_size = 32
    num_workers = 12
    output_name = f"cost_{folder}.data"

    instance_files, _ = split_instances([folder], 1, 0, 42)
    instance_files = instance_files[:20000]

    generate_data_rl(instance_files, H, max_steps, input_adapter_config, output_adapter_config, model, batch_size, num_workers, output_name)
# Out:
# Datos guardados en: /home/oscar/Escritorio/CPMP-Framework/data/cost_E5-5-R20.data (Tamaño 19962)
# Datos guardados en: /home/oscar/Escritorio/CPMP-Framework/data/cost_E5-5-R50.data (Tamaño 19999)
# Datos guardados en: /home/oscar/Escritorio/CPMP-Framework/data/cost_E5-5-R100.data (Tamaño 20000)
# Datos guardados en: /home/oscar/Escritorio/CPMP-Framework/data/cost_E5-5-RFull.data (Tamaño 19828)
